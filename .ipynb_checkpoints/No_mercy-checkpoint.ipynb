# %% [markdown]
# # My Favorite <font color='green'> Holiday Destination</font>

# %%
from IPython.display import YouTubeVideo
from IPython.display import Image

# %% [markdown]
# ### Why I love Koh-Pangan, Thailand.

# %% [markdown]
# - It has soul.
# - It is beatiful.
# - I feel free there.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('rlR3TPvjVaA', width=800, height=480)

# %%
h = input("Please type your name.")
# Out:
# Please type your name.Daniel

# %%
print(h)
# Out:
# Daniel

# %%
Image(filename='IMG.jpeg')

# %% [markdown]
# # Foo <font color='red'> Bar</font>
